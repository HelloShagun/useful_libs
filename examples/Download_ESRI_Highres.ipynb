# %% [markdown]
# <a href="https://colab.research.google.com/github/HelloShagun/useful_libs/blob/main/examples/Download_ESRI_Highres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipyleaflet ipywidgets Pillow requests
# !git clone https://github.com/HelloShagun/useful_libs

from google.colab import output
output.enable_custom_widget_manager()
import sys
sys.path.append("/content/useful_libs/basemap")

# %%
from wayback_viewer import WaybackViewer
#WaybackViewer().show()

# %% [markdown]
# ## Option 1 : UI

# %%
from useful_libs.basemap.wayback_viewer import WaybackViewer
from useful_libs.basemap.wayback_downloader import WaybackDownloader

# 1. Initialize the Map Viewer
# You can set the center to your specific Bengaluru coordinates
view = WaybackViewer(center=(12.9814, 77.7747), zoom=17)

# 2. Attach the Downloader logic
# This adds the Draw Tool and the Download UI to the map automatically
dl = WaybackDownloader(view)

# 3. Display the map
view.show()

### Now Draw a rectangle
### Click on Download images

# %% [markdown]
# ## Option 2 :via Script (No Drawing)

# %%
# Define your bounding box: (min_lat, min_lon, max_lat, max_lon)
my_bbox = (12.9801, 77.7734, 12.9827, 77.7759)

# Trigger the download manually at Zoom 18
dl.run_download(bbox=my_bbox, zoom=18, folder_name="whitefield_manual_export")

# %%
# 💡 Troubleshooting "ModuleNotFoundError"
# If Python says it cannot find useful_libs, it usually means your notebook is not in the folder immediately above useful_libs. You can fix this by adding your current path to the system:

# Python
# import sys
# import os
# sys.path.append(os.getcwd())
