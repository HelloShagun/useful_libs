# %% [markdown]
# <a href="https://colab.research.google.com/github/HelloShagun/useful_libs/blob/main/examples/basemap_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/HelloShagun/useful_libs

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
import sys
sys.path.append("/content/useful_libs/basemap")

from wayback_viewer import WaybackViewer
WaybackViewer().show()
